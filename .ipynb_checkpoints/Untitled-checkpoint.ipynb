# %%
import pandas as pd
import numpy as np
# this python magics will allow plot to be embedded into the notebook
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline

import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True) # one of the many color mappings

import os
os.chdir('C:/Mridul/Personal/Masters/Study Material and Resources/MS7331/Projects/Project1/OriginalFile/')

# %%
os.getcwd()
# Out:
# 'C:\\Mridul\\Personal\\Masters\\Study Material and Resources\\MS7331\\Projects\\Project1\\OriginalFile'

# %%
# now lets look at the data
# read in the csv file
df = pd.read_csv('loan.csv') 
df.head()
# Out:
# C:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599     5000.0       5000.0           4975.0   36 months
# 1  1077430    1314167     2500.0       2500.0           2500.0   60 months
# 2  1077175    1313524     2400.0       2400.0           2400.0   36 months
# 3  1076863    1277178    10000.0      10000.0          10000.0   36 months
# 4  1075358    1311748     3000.0       3000.0           3000.0   60 months
#
#    int_rate  installment grade sub_grade     ...      total_bal_il il_util  \
# 0     10.65       162.87     B        B2     ...               NaN     NaN
# 1     15.27        59.83     C        C4     ...               NaN     NaN
# ...

# %%
df.describe()
# Out:
#                  id     member_id      loan_amnt    funded_amnt  \
# count  8.873790e+05  8.873790e+05  887379.000000  887379.000000
# mean   3.246513e+07  3.500182e+07   14755.264605   14741.877625
# std    2.282734e+07  2.411335e+07    8435.455601    8429.897657
# min    5.473400e+04  7.047300e+04     500.000000     500.000000
# 25%    9.206643e+06  1.087713e+07    8000.000000    8000.000000
# 50%    3.443327e+07  3.709528e+07   13000.000000   13000.000000
# 75%    5.490814e+07  5.847135e+07   20000.000000   20000.000000
# max    6.861706e+07  7.354484e+07   35000.000000   35000.000000
#
#        funded_amnt_inv       int_rate    installment    annual_inc  \
# count    887379.000000  887379.000000  887379.000000  8.873750e+05
# mean      14702.464383      13.246740     436.717127  7.502759e+04
# std        8442.106732       4.381867     244.186593  6.469830e+04
# min           0.000000       5.320000      15.670000  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 74 columns):
# id                             887379 non-null int64
# member_id                      887379 non-null int64
# loan_amnt                      887379 non-null float64
# funded_amnt                    887379 non-null float64
# funded_amnt_inv                887379 non-null float64
# term                           887379 non-null object
# int_rate                       887379 non-null float64
# installment                    887379 non-null float64
# grade                          887379 non-null object
# sub_grade                      887379 non-null object
# emp_title                      835922 non-null object
# emp_length                     887379 non-null object
# home_ownership                 887379 non-null object
# annual_inc                     887375 non-null float64
# verification_status            887379 non-null object
# ...

# %%
df_grouped = df.groupby(by='grade')
print df_grouped.member_id.count()
ax2 = (df_grouped.member_id.count().plot(kind='barh', figsize=(5,5)))
# Out:
# grade
# A    148202
# B    254535
# C    245860
# D    139542
# E     70705
# F     23046
# G      5489
# Name: member_id, dtype: int64

# %%
# let's clean the dataset a little before moving on

# 1. Remove attributes that just arent useful for us
for col in ['id','funded_amnt_inv','sub_grade','emp_title','pymnt_plan','url','title','zip_code','earliest_cr_line','mths_since_last_delinq','mths_since_last_record','pub_rec','revol_bal','revol_util','total_acc','initial_list_status','out_prncp_inv','total_pymnt_inv','recoveries','collection_recovery_fee','last_pymnt_d','last_pymnt_amnt','next_pymnt_d','last_credit_pull_d','collections_12_mths_ex_med','policy_code','application_type','annual_inc_joint','dti_joint','verification_status_joint','open_acc_6m','open_il_6m','open_il_12m','open_il_24m','mths_since_rcnt_il','total_bal_il','il_util','open_rv_12m','open_rv_24m','max_bal_bc','all_util','total_rev_hi_lim','inq_fi','total_cu_tl','inq_last_12m']:
    if col in df:
        del df[col]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887379 entries, 0 to 887378
# Data columns (total 29 columns):
# member_id                      887379 non-null int64
# loan_amnt                      887379 non-null float64
# funded_amnt                    887379 non-null float64
# term                           887379 non-null object
# int_rate                       887379 non-null float64
# installment                    887379 non-null float64
# grade                          887379 non-null object
# emp_length                     887379 non-null object
# home_ownership                 887379 non-null object
# annual_inc                     887375 non-null float64
# verification_status            887379 non-null object
# issue_d                        887379 non-null object
# loan_status                    887379 non-null object
# desc                           126029 non-null object
# purpose                        887379 non-null object
# ...

# %%
summary(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-044cab1afcf3> in <module>()
# ----> 1 summary(df)
#
# NameError: name 'summary' is not defined

# %%
df['Int_Rate_Range'] = pd.cut(df.int_rate,[0,5,10,15,20,25,30],6,labels=['VeryLow','Low','Medium', 'High', 'VeryHigh', 'Expensive']) # this creates a new variable
df.Int_Rate_Range.describe()
# Out:
# count     887379
# unique         5
# top       Medium
# freq      372060
# Name: Int_Rate_Range, dtype: object

# %%
# Loan Classifier tells whether the loan is Bad Loan or was Paid Off completely
df['Loan_Classifier'] = 0
df['Delinq_Classifier'] = 'NA'

# %%
df.loc[df['loan_status'] == 'Charged Off' , 'Loan_Classifier'] = 'Bad'
df.loc[df['loan_status'] == 'Default' , 'Loan_Classifier'] = 'Bad'
df.loc[df['loan_status'] == 'Late (31-120 days)' , 'Loan_Classifier'] = 'Bad'
df.loc[df['loan_status'] == 'Late (16-30 days)' , 'Loan_Classifier'] = 'Bad'
df.loc[df['loan_status'] == 'Does not meet the credit policy. Status:Charged Off' , 'Loan_Classifier'] = 'Bad'

df.loc[df['loan_status'] == 'Fully Paid' , 'Loan_Classifier'] = 'Good'
df.loc[df['loan_status'] == 'Does not meet the credit policy. Status:Fully Paid' , 'Loan_Classifier'] = 'Good'

df.loc[df['loan_status'] == 'Current' , 'Loan_Classifier'] = 'Running'
df.loc[df['loan_status'] == 'In Grace Period' , 'Loan_Classifier'] = 'Running'
df.loc[df['loan_status'] == 'Issued' , 'Loan_Classifier'] = 'Running'

# %%
df.loc[df['delinq_2yrs'] == 0 , 'Delinq_Classifier'] = 'NeverDelinq'
df.loc[df['delinq_2yrs'] > 0 , 'Delinq_Classifier'] = 'Delinq'

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(20, 20))
df_grouped = df.groupby(by=['grade'])
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(color='grey')
ax1.set_title(r'Loan Amount')
ax1 = (df_grouped.loan_amnt.sum()/1000000).plot(kind='barh', figsize=(10,5))
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(color='blue')
ax2.set_title(r'Interest Rate')
ax2 = df_grouped.int_rate.mean().plot(kind='barh')
ax3 = fig.add_subplot(2, 2, 3)
ax3.plot(color='red')
ax3.set_title(r'Funded Amount')
ax3 = (df_grouped.funded_amnt.sum()/1000000).plot(kind='barh')
ax4 = fig.add_subplot(2, 2, 4)
ax4.plot(color='green')
ax4.set_title(r'Avg. Annual Income')
ax4 = (df_grouped.annual_inc.mean()).plot(kind='barh')

# %%
plt.style.use('ggplot')
fig = plt.figure(figsize=(20, 20))
df_grouped = df.groupby(by=['Loan_Classifier'])
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(color='grey')
ax1.set_title(r'Loan Amount')
ax1 = (df_grouped.loan_amnt.sum()).plot(kind='barh', figsize=(10,5))
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(color='blue')
ax2.set_title(r'Interest Rate')
ax2 = df_grouped.int_rate.mean().plot(kind='barh')

# %%
df.boxplot(column='int_rate', by = ['term','Loan_Classifier'], figsize=(15,10))

# %%
df.boxplot(column='int_rate', by = ['grade','Loan_Classifier'], figsize=(18,10))

# %%
plt.style.use('ggplot')

df_grouped = df.groupby(by=['grade','Loan_Classifier'])
ax = (df_grouped.loan_amnt.sum()).plot(kind='barh', figsize=(10,10))

# %%
df.boxplot(column='loan_amnt', by = 'purpose', figsize=(18,5))

# %%
fig = plt.figure(figsize=(15, 10))

ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(color='blue')
ax1 = (df_grouped.loan_amnt.sum()/1000000).plot(kind='barh')
ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(color='red')
ax2 = (df_grouped.funded_amnt.sum()/1000000).plot(kind='barh')

# %%
# now lets group with the new variable
df_grouped = df.groupby(by=['grade','Int_Rate_Range'])
print "Percentage of people in each group:"
Perc_in_each_group =  df_grouped.member_id.count() / df.member_id.count() *100
ax2 = (Perc_in_each_group.plot(kind='barh', stacked = True))
print Perc_in_each_group
# Out:
# Percentage of people in each group:
# grade  Int_Rate_Range
# A      Low               16.701094
# B      Low                9.841342
#        Medium            18.842569
# C      Low                0.003832
#        Medium            22.832859
#        High               4.869622
# D      Low                0.003268
#        Medium             0.221326
#        High              15.309242
#        VeryHigh           0.191350
# E      Low                0.002479
#        Medium             0.031216
#        High               4.624292
#        VeryHigh           3.309860
# F      Low                0.000451
#        High               0.091393
#        VeryHigh           2.272422
#        Expensive          0.232820
# G      High               0.017918
#        VeryHigh           0.101760
#        Expensive          0.498885
# Name: member_id, dtype: float64

# %%
df.boxplot(column='int_rate', by = ['Delinq_Classifier','Loan_Classifier'], figsize=(20,10))

# %%
# now lets group with the new variable
df_grouped = df.groupby(by=['addr_state'])
print "Percentage of people in each state:"
Perc_in_each_state =  df_grouped.member_id.count() / df.member_id.count() *100
ax2 = Perc_in_each_state.plot(kind='barh', figsize=(10,12), stacked = True)
# Out:
# Percentage of people in each state:
